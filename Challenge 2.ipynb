# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order_lines = pd.read_excel("C:\\Users\\soumy\\Downloads\\Order_lines.xlsx")
order_lines
# Out:
#             order_id      order_placement_date  customer_id  PRODUCT_ID  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
product = pd.read_excel("C:\\Users\\soumy\\Downloads\\product.xlsx")
product
# Out:
#        product_name  PRODUCT_ID   category
# 0       AM Milk 500    25891101      Dairy
# 1       AM Milk 250    25891102      Dairy
# 2       AM Milk 100    25891103      Dairy
# 3     AM Butter 100    25891201      Dairy
# 4     AM Butter 250    25891202      Dairy
# 5     AM Butter 500    25891203      Dairy
# 6       AM Ghee 250    25891301      Dairy
# 7       AM Ghee 150    25891302      Dairy
# 8       AM Ghee 100    25891303      Dairy
# 9       AM Curd 250    25891401      Dairy
# 10      AM Curd 100    25891402      Dairy
# 11       AM Curd 50    25891403      Dairy
# 12  AM Biscuits 750    25891501       Food
# 13  AM Biscuits 500    25891502       Food
# 14  AM Biscuits 250    25891503       Food
# 15       AM Tea 500    25891601  beverages
# 16       AM Tea 250    25891602  beverages
# 17       AM Tea 100    25891603  beverages

# %%
dict1 = {25891101:'Dairy',25891102:'Dairy', 25891103:'Dairy',25891201:'Dairy',25891202:'Dairy',25891203:'Dairy',
        25891301:'Dairy',25891302:'Dairy', 25891303:'Dairy',25891401:'Dairy',25891402:'Dairy',25891403:'Dairy',
        25891501:'Food',25891502:'Food', 25891503:'Food',25891601:'beverages',25891602:'beverages',25891603:'beverages',
       }

# %%
order_lines['product_category'] = order_lines['PRODUCT_ID'].replace(dict1)
order_lines
# Out:
#             order_id      order_placement_date  customer_id  PRODUCT_ID  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
dict2 = {25891101:'Milk 500',25891102:'Milk 250', 25891103:'Milk 100',25891201:'Butter 100',25891202:'Butter 250',25891203:'Butter 500',
        25891301:'Ghee 250',25891302:'Ghee 150', 25891303:'Ghee 100',25891401:'Curd 250',25891402:'Curd 100',25891403:'Curd 50',
        25891501:'Biscuits 750',25891502:'Biscuits 500', 25891503:'Biscuits 250',25891601:'Tea 500',25891602:'Tea 250',25891603:'Tea 100',
       }

# %%
order_lines['product_name'] = order_lines['PRODUCT_ID'].replace(dict2)
order_lines
# Out:
#             order_id      order_placement_date  customer_id  PRODUCT_ID  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
order_lines.rename(columns={'PRODUCT_ID': 'product_id'}, inplace=True)
order_lines
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
dim_customers = pd.read_csv("C:\\Users\\soumy\\Downloads\\ML Projects\\Challenge 2\\c2-input-for-participants-1\\C2 Input for participants\\dim_customers.csv")
dim_customers
# Out:
#     customer_id      customer_name       city
# 0        789201          Rel Fresh      Surat
# 1        789202          Rel Fresh  Ahmedabad
# 2        789203          Rel Fresh   Vadodara
# 3        789301  Expression Stores      Surat
# 4        789303  Expression Stores   Vadodara
# 5        789101       Vijay Stores      Surat
# 6        789102       Vijay Stores  Ahmedabad
# 7        789103       Vijay Stores   Vadodara
# 8        789121           Coolblue  Ahmedabad
# 9        789122           Coolblue   Vadodara
# 10       789220       Atlas Stores      Surat
# 11       789221       Atlas Stores  Ahmedabad
# 12       789320     Chiptec Stores      Surat
# 13       789321     Chiptec Stores  Ahmedabad
# 14       789401        Propel Mart      Surat
# 15       789402        Propel Mart  Ahmedabad
# 16       789403        Propel Mart   Vadodara
# 17       789420         Lotus Mart      Surat
# 18       789421         Lotus Mart  Ahmedabad
# ...

# %%
df = pd.merge(order_lines,dim_customers[['customer_name','city','customer_id']],on = ['customer_id'],how = 'left')
df
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
df1 = df.copy()

# %%
df1
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57096 entries, 0 to 57095
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              57096 non-null  object
#  1   order_placement_date  57096 non-null  object
#  2   customer_id           57096 non-null  int64
#  3   product_id            57096 non-null  int64
#  4   order_qty             57096 non-null  int64
#  5   agreed_delivery_date  57096 non-null  object
#  6   actual_delivery_date  57096 non-null  object
#  7   delivery_qty          57096 non-null  int64
#  8   In Full               57096 non-null  int64
#  9   On Time               57096 non-null  int64
#  10  On Time In Full       57096 non-null  int64
#  11  product_category      57096 non-null  object
#  12  product_name          57096 non-null  object
#  13  customer_name         57096 non-null  object
#  14  city                  57096 non-null  object
# ...

# %%
df1.columns
# Out:
# Index(['order_id', 'order_placement_date', 'customer_id', 'product_id',
#        'order_qty', 'agreed_delivery_date', 'actual_delivery_date',
#        'delivery_qty', 'In Full', 'On Time', 'On Time In Full',
#        'product_category', 'product_name', 'customer_name', 'city'],
#       dtype='object')

# %%
customer = df1.drop(columns = ['order_id', 'order_placement_date','product_category','order_qty','product_id','agreed_delivery_date', 'actual_delivery_date', 'delivery_qty','product_name'])
customer
# Out:
#        customer_id  In Full  On Time  On Time In Full   customer_name  \
# 0           789203        1        1                1       Rel Fresh
# 1           789320        1        1                1  Chiptec Stores
# 2           789320        0        1                0  Chiptec Stores
# 3           789220        1        1                1    Atlas Stores
# 4           789703        1        1                1    Sorefoz Mart
# ...            ...      ...      ...              ...             ...
# 57091       789420        1        1                1      Lotus Mart
# 57092       789122        0        1                0        Coolblue
# 57093       789702        0        1                0    Sorefoz Mart
# 57094       789221        0        1                0    Atlas Stores
# 57095       789202        1        0                0       Rel Fresh
#
#             city
# 0       Vadodara
# 1          Surat
# 2          Surat
# 3          Surat
# 4       Vadodara
# ...

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57096 entries, 0 to 57095
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      57096 non-null  int64
#  1   In Full          57096 non-null  int64
#  2   On Time          57096 non-null  int64
#  3   On Time In Full  57096 non-null  int64
#  4   customer_name    57096 non-null  object
#  5   city             57096 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 3.0+ MB

# %% [markdown]
# ## Analysing by city Name

# %%
## Analysing by city Name
customer.groupby('city')['In Full'].sum()
# Out:
# city
# Ahmedabad    13293
# Surat        11898
# Vadodara     12470
# Name: In Full, dtype: int64

# %%
customer.groupby('city')['In Full'].sum().plot(kind='bar', figsize=(5, 3))
# Out:
# <Axes: xlabel='city'>

# %%
## We can see that customers from Ahmedabad get highest number of Infull order

# %%
## Analysing On Time

# %%
customer.groupby('city')['On Time'].sum()
# Out:
# city
# Ahmedabad    13774
# Surat        13144
# Vadodara     13687
# Name: On Time, dtype: int64

# %%
customer.groupby('city')['On Time'].sum().plot(kind='bar', figsize=(5, 3),color = 'red')
# Out:
# <Axes: xlabel='city'>

# %%
customer.groupby('city')['On Time In Full'].sum()
# Out:
# city
# Ahmedabad    9509
# Surat        9017
# Vadodara     8854
# Name: On Time In Full, dtype: int64

# %%
customer.groupby('city')['On Time In Full'].sum().plot(kind='bar', figsize=(5, 3),color = 'green')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# ## Analysing by customer name

# %%
customer.groupby('customer_name')['In Full'].sum().sort_values()
# Out:
# customer_name
# Info Stores          1712
# Coolblue             1720
# Elite Mart           1732
# Sorefoz Mart         1752
# Viveks Stores        2417
# Logic Stores         2423
# Chiptec Stores       2440
# Atlas Stores         2450
# Expression Stores    2485
# Expert Mart          2512
# Acclaimed Stores     2827
# Lotus Mart           2926
# Vijay Stores         2941
# Rel Fresh            3654
# Propel Mart          3670
# Name: In Full, dtype: int64

# %%
customer.groupby('customer_name')['In Full'].sum().sort_values().plot(kind='bar', figsize=(5, 3))
# Out:
# <Axes: xlabel='customer_name'>

# %%
customer.groupby('customer_name')['On Time'].sum().sort_values().plot(kind='bar', figsize=(5, 3),color = 'red')
# Out:
# <Axes: xlabel='customer_name'>

# %%
customer.groupby('customer_name')['On Time In Full'].sum().sort_values().plot(kind='bar', figsize=(5, 3),color = 'green')
# Out:
# <Axes: xlabel='customer_name'>

# %%
# On Time - Vijay Stores
# In full - Propel Mart
# On Time In full - Propel Mart

# %%
# Analysing Based on City of The Customer

# %%
customer_propel = customer[customer['customer_name'] == 'Propel Mart']

# %%
customer_propel.groupby('city')['In Full'].sum()
# Out:
# city
# Ahmedabad    1256
# Surat        1209
# Vadodara     1205
# Name: In Full, dtype: int64

# %%
customer_propel.groupby('city')['On Time'].sum()
# Out:
# city
# Ahmedabad    1425
# Surat        1371
# Vadodara     1359
# Name: On Time, dtype: int64

# %%
customer_propel.groupby('city')['On Time In Full'].sum()
# Out:
# city
# Ahmedabad    1086
# Surat        1034
# Vadodara     1037
# Name: On Time In Full, dtype: int64

# %%
## So, here also we can see that the Customer (Propel Mart) having highest number of 'In time and On full In full' delivery, has received from Ahmedabad city part.

# %%
customer[customer['customer_name'] == 'Vijay Stores'].groupby('city')['On Time'].sum()
# Out:
# city
# Ahmedabad    1379
# Surat        1382
# Vadodara     1446
# Name: On Time, dtype: int64

# %%
## The Highest 'On Time' delivery has been excutated to Vadodhara Office

# %% [markdown]
# ## Analysing using Customer ID

# %%
customer.groupby('customer_id')['In Full'].sum().sort_values().tail(5).plot(kind='bar', figsize=(5, 3))
# Out:
# <Axes: xlabel='customer_id'>

# %%
customer.groupby('customer_id')['On Time'].sum().sort_values().tail(5).plot(kind='bar', figsize=(5, 3),color = 'red')
# Out:
# <Axes: xlabel='customer_id'>

# %%
customer.groupby('customer_id')['On Time In Full'].sum().sort_values().tail(5).plot(kind='bar', figsize=(5, 3),color='green')
# Out:
# <Axes: xlabel='customer_id'>

# %%
list = [789420,789303,789402,789202,789622,789703,789103,789902]
customer[customer['customer_id'].isin(list)]
# Out:
#        customer_id  In Full  On Time  On Time In Full customer_name       city
# 4           789703        1        1                1  Sorefoz Mart   Vadodara
# 6           789420        1        0                0    Lotus Mart      Surat
# 7           789420        1        0                0    Lotus Mart      Surat
# 13          789902        1        1                1    Elite Mart  Ahmedabad
# 17          789402        1        0                0   Propel Mart  Ahmedabad
# ...            ...      ...      ...              ...           ...        ...
# 57074       789420        1        1                1    Lotus Mart      Surat
# 57075       789402        1        1                1   Propel Mart  Ahmedabad
# 57076       789902        1        1                1    Elite Mart  Ahmedabad
# 57091       789420        1        1                1    Lotus Mart      Surat
# 57095       789202        1        0                0     Rel Fresh  Ahmedabad
#
# ...

# %%
customer[customer['customer_id'].isin(list)][['customer_id','customer_name','city']].drop_duplicates()
# Out:
#     customer_id      customer_name       city
# 4        789703       Sorefoz Mart   Vadodara
# 6        789420         Lotus Mart      Surat
# 13       789902         Elite Mart  Ahmedabad
# 17       789402        Propel Mart  Ahmedabad
# 45       789103       Vijay Stores   Vadodara
# 50       789202          Rel Fresh  Ahmedabad
# 55       789303  Expression Stores   Vadodara
# 80       789622        Expert Mart   Vadodara

# %%
# Best Performance based on
# On time - Vijay Stores(Vadodara)
# In Full - Expert Mart(Vadodara)
# On Time In full - Propel Mart(Ahmedabad)

# %%
customer[['In Full','On Time','On Time In Full']].corr()
# Out:
#                   In Full   On Time  On Time In Full
# In Full          1.000000  0.048656         0.689553
# On Time          0.048656  1.000000         0.611724
# On Time In Full  0.689553  0.611724         1.000000

# %%
# Here we can see 'In Full' influences 'On Time In Full' more than 'On Time'

# %%
df1
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
customer2 = df1[['customer_name','order_qty','In Full','On Time','On Time In Full']]
customer2
# Out:
#         customer_name  order_qty  In Full  On Time  On Time In Full
# 0           Rel Fresh        110        1        1                1
# 1      Chiptec Stores        347        1        1                1
# 2      Chiptec Stores        187        0        1                0
# 3        Atlas Stores        235        1        1                1
# 4        Sorefoz Mart        176        1        1                1
# ...               ...        ...      ...      ...              ...
# 57091      Lotus Mart         24        1        1                1
# 57092        Coolblue         67        0        1                0
# 57093    Sorefoz Mart         41        0        1                0
# 57094    Atlas Stores         92        0        1                0
# 57095       Rel Fresh         29        1        0                0
#
# [57096 rows x 5 columns]

# %%
customer2.groupby('customer_name')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by = 'order_qty')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\1594641489.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   customer2.groupby('customer_name')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by = 'order_qty')
#                    order_qty  In Full  On Time  On Time In Full
# customer_name
# Logic Stores          755835     2423     2716             2018
# Chiptec Stores        756652     2440     2703             2032
# Viveks Stores         760300     2417     2686             2030
# Atlas Stores          760711     2450     2733             2071
# Sorefoz Mart          765536     1752     2782             1496
# Info Stores           767833     1712     2683             1403
# Expression Stores     768746     2485     2744             2057
# Elite Mart            772140     1732     2783             1474
# Coolblue              776624     1720      895              459
# ...

# %%
## We can see top 5 customer in terms of order quantity - Acclamied stores, propel Mart, Rel Fresh , Lotus Mart, Vijay Stores

# %%
customer2.groupby('customer_name')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\3529066357.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   customer2.groupby('customer_name')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.798068  0.245394         0.215890
# In Full           0.798068  1.000000  0.484753         0.626322
# On Time           0.245394  0.484753  1.000000         0.936014
# On Time In Full   0.215890  0.626322  0.936014         1.000000

# %%
# By the correlation Matrix, we can conclude that Order Quantity influences the 'In full' order more than 'On time' and 'On time In Full'
# On Time in full is influenced more by On Time (0.93) than In full(0.62)

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
grouped_infull= df.groupby('customer_name')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
grouped_infull['Percentage of 1s'] = (grouped_infull['sum'] / grouped_infull['count']) * 100
grouped_infull.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar')
# Out:
# <Axes: xlabel='customer_name'>

# %%
# In full% highest for Propel Mart, Expert Mart, Chiptec Stores, Atlas Stores, Expression Stores

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
grouped_ot= df.groupby('customer_name')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
grouped_ot['Percentage of 1s'] = (grouped_ot['sum'] / grouped_ot['count']) * 100
grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color = 'red')
# Out:
# <Axes: xlabel='customer_name'>

# %%
# Here is the Top 5 %On time Delivery Propel Mart, Rel Fresh, Sorefoz Mart, Vijay Stores

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
grouped_otif= df.groupby('customer_name')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
grouped_otif['Percentage of 1s'] = (grouped_otif['sum'] / grouped_otif['count']) * 100
grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color = 'green')
# Out:
# <Axes: xlabel='customer_name'>

# %%
# Here is the Top 5 %On Time In full delivery - Propel Mart, Rel Fresh, Atlas stores, Expert Mart, Vivek Stores

# %%
display(grouped_otif,grouped_infull,grouped_ot)
# Out:
#                     sum  count  Percentage of 1s
# customer_name
# Acclaimed Stores    731   4797         15.238691
# Atlas Stores       2071   3246         63.801602
# Chiptec Stores     2032   3227         62.968702
# Coolblue            459   3338         13.750749
# Elite Mart         1474   3284         44.884287
# Expert Mart        2117   3328         63.611779
# Expression Stores  2057   3301         62.314450
# Info Stores        1403   3227         43.476914
# Logic Stores       2018   3257         61.958858
# Lotus Mart          782   4870         16.057495
# Propel Mart        3157   4853         65.052545
# Rel Fresh          3090   4902         63.035496
# Sorefoz Mart       1496   3281         45.595855
# Vijay Stores       2463   4965         49.607251
# Viveks Stores      2030   3220         63.043478
#                     sum  count  Percentage of 1s
# customer_name
# Acclaimed Stores   2827   4797         58.932666
# ...

# %% [markdown]
# ## Analysing by city

# %%
city = df1[['city','In Full','On Time','On Time In Full']]
city
# Out:
#             city  In Full  On Time  On Time In Full
# 0       Vadodara        1        1                1
# 1          Surat        1        1                1
# 2          Surat        0        1                0
# 3          Surat        1        1                1
# 4       Vadodara        1        1                1
# ...          ...      ...      ...              ...
# 57091      Surat        1        1                1
# 57092   Vadodara        0        1                0
# 57093  Ahmedabad        0        1                0
# 57094  Ahmedabad        0        1                0
# 57095  Ahmedabad        1        0                0
#
# [57096 rows x 4 columns]

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
city_grouped_otif= df1.groupby('city')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
city_grouped_otif['Percentage of 1s'] = (city_grouped_otif['sum'] /city_grouped_otif['count']) * 100
city_grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color = 'green')
# Out:
# <Axes: xlabel='city'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
city_grouped_ot= df1.groupby('city')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
city_grouped_ot['Percentage of 1s'] = (city_grouped_ot['sum'] /city_grouped_ot['count']) * 100
city_grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color = 'red')
# Out:
# <Axes: xlabel='city'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
city_grouped_if= df1.groupby('city')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
city_grouped_if['Percentage of 1s'] = (city_grouped_if['sum'] /city_grouped_if['count']) * 100
city_grouped_if.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color = 'red')
# Out:
# <Axes: xlabel='city'>

# %%
display(city_grouped_if,city_grouped_ot,city_grouped_otif)
# Out:
#              sum  count  Percentage of 1s
# city
# Ahmedabad  13293  19676         67.559463
# Surat      11898  17842         66.685349
# Vadodara   12470  19578         63.693942
#              sum  count  Percentage of 1s
# city
# Ahmedabad  13774  19676         70.004066
# Surat      13144  17842         73.668871
# Vadodara   13687  19578         69.910103
#             sum  count  Percentage of 1s
# city
# Ahmedabad  9509  19676         48.327912
# Surat      9017  17842         50.538056
# Vadodara   8854  19578         45.224231

# %%
# In full - Ahmedabad
# On Time - Surat
# On Time In Full - Surat

# %% [markdown]
# ## Analysising by product category

# %%
product_type = df1[['product_category','order_qty','In Full','On Time','On Time In Full']]
product_type
# Out:
#       product_category  order_qty  In Full  On Time  On Time In Full
# 0            beverages        110        1        1                1
# 1                Dairy        347        1        1                1
# 2                Dairy        187        0        1                0
# 3                Dairy        235        1        1                1
# 4                Dairy        176        1        1                1
# ...                ...        ...      ...      ...              ...
# 57091            Dairy         24        1        1                1
# 57092            Dairy         67        0        1                0
# 57093            Dairy         41        0        1                0
# 57094            Dairy         92        0        1                0
# 57095            Dairy         29        1        0                0
#
# [57096 rows x 5 columns]

# %%
product_type.groupby('product_category')['order_qty','In Full','On Time','On Time In Full'].sum()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\550406742.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   product_type.groupby('product_category')['order_qty','In Full','On Time','On Time In Full'].sum()
#                   order_qty  In Full  On Time  On Time In Full
# product_category
# Dairy              10564711    25123    26975            18222
# Food                1678481     6337     6875             4659
# beverages           1183744     6201     6755             4499

# %%
product_type.groupby('product_category')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\1201343909.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   product_type.groupby('product_category')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.999175  0.999130         0.999326
# In Full           0.999175  1.000000  0.999999         0.999992
# On Time           0.999130  0.999999  1.000000         0.999987
# On Time In Full   0.999326  0.999992  0.999987         1.000000

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pt_grouped_if= df1.groupby('product_category')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pt_grouped_if['Percentage of 1s'] = (pt_grouped_if['sum'] /pt_grouped_if['count']) * 100
pt_grouped_if.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar')
# Out:
# <Axes: xlabel='product_category'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pt_grouped_ot= df1.groupby('product_category')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pt_grouped_ot['Percentage of 1s'] = (pt_grouped_ot['sum'] /pt_grouped_ot['count']) * 100
pt_grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='product_category'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pt_grouped_otif= df1.groupby('product_category')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pt_grouped_otif['Percentage of 1s'] = (pt_grouped_otif['sum'] /pt_grouped_otif['count']) * 100
pt_grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='product_category'>

# %%
display(pt_grouped_if,pt_grouped_ot,pt_grouped_otif)
# Out:
#                     sum  count  Percentage of 1s
# product_category
# Dairy             25123  38096         65.946556
# Food               6337   9539         66.432540
# beverages          6201   9461         65.542754
#                     sum  count  Percentage of 1s
# product_category
# Dairy             26975  38096         70.807959
# Food               6875   9539         72.072544
# beverages          6755   9461         71.398372
#                     sum  count  Percentage of 1s
# product_category
# Dairy             18222  38096         47.831793
# Food               4659   9539         48.841598
# beverages          4499   9461         47.553113

# %% [markdown]
# ## Analyising by the product

# %%
product = df1[['order_qty','product_name','In Full','On Time', 'On Time In Full']]
product
# Out:
#        order_qty product_name  In Full  On Time  On Time In Full
# 0            110      Tea 500        1        1                1
# 1            347   Butter 500        1        1                1
# 2            187   Butter 500        0        1                0
# 3            235   Butter 500        1        1                1
# 4            176   Butter 500        1        1                1
# ...          ...          ...      ...      ...              ...
# 57091         24     Ghee 100        1        1                1
# 57092         67     Ghee 100        0        1                0
# 57093         41     Ghee 100        0        1                0
# 57094         92     Ghee 100        0        1                0
# 57095         29     Ghee 100        1        0                0
#
# [57096 rows x 5 columns]

# %%
product['product_name'] = product['product_name'].str.split(' ').str[0]
product
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\4038775445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product['product_name'] = product['product_name'].str.split(' ').str[0]
#        order_qty product_name  In Full  On Time  On Time In Full
# 0            110          Tea        1        1                1
# 1            347       Butter        1        1                1
# 2            187       Butter        0        1                0
# 3            235       Butter        1        1                1
# 4            176       Butter        1        1                1
# ...          ...          ...      ...      ...              ...
# 57091         24         Ghee        1        1                1
# ...

# %%
product.groupby('product_name')['order_qty','In Full','On Time','On Time In Full'].sum()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\3467289009.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   product.groupby('product_name')['order_qty','In Full','On Time','On Time In Full'].sum()
#               order_qty  In Full  On Time  On Time In Full
# product_name
# Biscuits        1678481     6337     6875             4659
# Butter          2859770     6231     6777             4502
# Curd            3323993     6313     6770             4602
# Ghee             571204     6266     6639             4492
# Milk            3809744     6313     6789             4626
# Tea             1183744     6201     6755             4499

# %%
product.groupby('product_name')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\1010992688.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   product.groupby('product_name')['order_qty','In Full','On Time','On Time In Full'].sum().corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.385743  0.430464         0.494279
# In Full           0.385743  1.000000  0.456989         0.903784
# On Time           0.430464  0.456989  1.000000         0.749677
# On Time In Full   0.494279  0.903784  0.749677         1.000000

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
p_grouped_otif= product.groupby('product_name')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
p_grouped_otif['Percentage of 1s'] = (p_grouped_otif['sum'] /p_grouped_otif['count']) * 100
p_grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color='green',figsize=(5,3))
# Out:
# <Axes: xlabel='product_name'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
p_grouped_ot= product.groupby('product_name')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
p_grouped_ot['Percentage of 1s'] = (p_grouped_ot['sum'] /p_grouped_ot['count']) * 100
p_grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color='red',figsize=(5,3))
# Out:
# <Axes: xlabel='product_name'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
p_grouped_if= product.groupby('product_name')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
p_grouped_if['Percentage of 1s'] = (p_grouped_if['sum'] /p_grouped_if['count']) * 100
p_grouped_if.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='product_name'>

# %%
display(p_grouped_if,p_grouped_ot,p_grouped_otif)
# Out:
#                sum  count  Percentage of 1s
# product_name
# Biscuits      6337   9539         66.432540
# Butter        6231   9567         65.130135
# Curd          6313   9502         66.438644
# Ghee          6266   9507         65.909330
# Milk          6313   9520         66.313025
# Tea           6201   9461         65.542754
#                sum  count  Percentage of 1s
# product_name
# Biscuits      6875   9539         72.072544
# Butter        6777   9567         70.837253
# Curd          6770   9502         71.248158
# Ghee          6639   9507         69.832755
# Milk          6789   9520         71.313025
# Tea           6755   9461         71.398372
#                sum  count  Percentage of 1s
# product_name
# Biscuits      4659   9539         48.841598
# Butter        4502   9567         47.057594
# Curd          4602   9502         48.431909
# Ghee          4492   9507         47.249395
# Milk          4626   9520         48.592437
# ...

# %%
## On Time - Biscuits
## In Full - Curd ~ Biscuits
## On Time In Full - Biscuits

# %%
## All are having very close value. So, product doesn't influence the 'On Time', 'In Full', 'On Time In Full'

# %% [markdown]
# ## Analysing by product_id

# %%
len(df1['product_id'].unique())
# Out:
# 18

# %%
pi = df1[['product_id','order_qty','In Full','On Time','On Time In Full']]
pi
# Out:
#        product_id  order_qty  In Full  On Time  On Time In Full
# 0        25891601        110        1        1                1
# 1        25891203        347        1        1                1
# 2        25891203        187        0        1                0
# 3        25891203        235        1        1                1
# 4        25891203        176        1        1                1
# ...           ...        ...      ...      ...              ...
# 57091    25891303         24        1        1                1
# 57092    25891303         67        0        1                0
# 57093    25891303         41        0        1                0
# 57094    25891303         92        0        1                0
# 57095    25891303         29        1        0                0
#
# [57096 rows x 5 columns]

# %%
pi.groupby('product_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values('order_qty')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\652938435.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pi.groupby('product_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values('order_qty')
#             order_qty  In Full  On Time  On Time In Full
# product_id
# 25891303       186186     2037     2170             1452
# 25891301       191494     2088     2227             1502
# 25891302       193524     2141     2242             1538
# 25891602       392461     2048     2235             1498
# 25891603       394712     2047     2245             1480
# 25891601       396571     2106     2275             1521
# 25891501       556996     2149     2289             1596
# 25891502       558119     2112     2301             1552
# 25891503       563366     2076     2285             1511
# 25891202       933107     1985     2229             1460
# ...

# %%
pi.groupby('product_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values('order_qty').corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\879528336.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pi.groupby('product_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values('order_qty').corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.166178  0.322168         0.325739
# In Full           0.166178  1.000000  0.519427         0.840047
# On Time           0.322168  0.519427  1.000000         0.598477
# On Time In Full   0.325739  0.840047  0.598477         1.000000

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pi_grouped_if= pi.groupby('product_id')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pi_grouped_if['Percentage of 1s'] = (pi_grouped_if['sum'] /pi_grouped_if['count']) * 100
pi_grouped_if.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='product_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pi_grouped_ot= pi.groupby('product_id')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pi_grouped_ot['Percentage of 1s'] = (pi_grouped_ot['sum'] /pi_grouped_ot['count']) * 100
pi_grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',color='red',figsize=(5,3))
# Out:
# <Axes: xlabel='product_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
pi_grouped_otif= pi.groupby('product_id')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
pi_grouped_otif['Percentage of 1s'] = (pi_grouped_otif['sum'] /pi_grouped_otif['count']) * 100
pi_grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='green')
# Out:
# <Axes: xlabel='product_id'>

# %%
display(pi_grouped_otif,pi_grouped_if,pi_grouped_ot)
# Out:
#              sum  count  Percentage of 1s
# product_id
# 25891101    1558   3139         49.633641
# 25891102    1519   3197         47.513294
# 25891103    1549   3184         48.649497
# 25891201    1524   3170         48.075710
# 25891202    1460   3125         46.720000
# 25891203    1518   3272         46.393643
# 25891301    1502   3200         46.937500
# 25891302    1538   3209         47.927703
# 25891303    1452   3098         46.868948
# 25891401    1542   3138         49.139579
# 25891402    1547   3177         48.693736
# 25891403    1513   3187         47.474114
# 25891501    1596   3158         50.538315
# 25891502    1552   3195         48.575900
# 25891503    1511   3186         47.426240
# 25891601    1521   3184         47.770101
# 25891602    1498   3143         47.661470
# 25891603    1480   3134         47.223995
#              sum  count  Percentage of 1s
# product_id
# 25891101    2119   3139         67.505575
# 25891102    2107   3197         65.905536
# ...

# %%
# Based on the Order qty Top 5 in terms of Order id  - .......

# %%
# %In full, %On Time, %On Time In Full are not influenced by Product

# %%
df1[df1['product_id'].isin([25891101,25891102,25891103,25891402,25891403])]['product_category'].unique()
# Out:
# array(['Dairy'], dtype=object)

# %%
df1[df1['product_id'].isin([25891101,25891102,25891103,25891402,25891403])]['product_name'].unique()
# Out:
# array(['Milk 250', 'Curd 50', 'Milk 100', 'Curd 100', 'Milk 500'],
#       dtype=object)

# %%
## We can con conclude that Milke and Curd The dairy product are the best suppliers

# %% [markdown]
# ## Analysing by Date

# %%
df1
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...

# %%
date = df1[['agreed_delivery_date','order_qty','On Time','In Full','On Time In Full']]

# %%
date
# Out:
#              agreed_delivery_date  order_qty  On Time  In Full  \
# 0           Friday, March 4, 2022        110        1        1
# 1        Wednesday, March 2, 2022        347        1        1
# 2         Thursday, March 3, 2022        187        1        0
# 3           Friday, March 4, 2022        235        1        1
# 4         Thursday, March 3, 2022        176        1        1
# ...                           ...        ...      ...      ...
# 57091  Wednesday, August 31, 2022         24        1        1
# 57092  Wednesday, August 31, 2022         67        1        0
# 57093  Wednesday, August 31, 2022         41        1        0
# 57094  Wednesday, August 31, 2022         92        1        0
# 57095  Wednesday, August 31, 2022         29        0        1
#
#        On Time In Full
# 0                    1
# 1                    1
# 2                    0
# 3                    1
# 4                    1
# ...                ...
# 57091                1
# ...

# %%
def extract_month(date_series):
    # Split the string by comma and space, and select the second part which contains the month
    return date_series.str.split(', ').str[1].str.split(' ').str[0]

# %%
date1=date.copy()

# %%
date1['month'] = extract_month(date1['agreed_delivery_date'])
date1.drop(columns=['agreed_delivery_date'],inplace=True)
date1
# Out:
#        order_qty  On Time  In Full  On Time In Full   month
# 0            110        1        1                1   March
# 1            347        1        1                1   March
# 2            187        1        0                0   March
# 3            235        1        1                1   March
# 4            176        1        1                1   March
# ...          ...      ...      ...              ...     ...
# 57091         24        1        1                1  August
# 57092         67        1        0                0  August
# 57093         41        1        0                0  August
# 57094         92        1        0                0  August
# 57095         29        0        1                0  August
#
# [57096 rows x 5 columns]

# %%
date1.groupby('month')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\307585784.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date1.groupby('month')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
#         order_qty  In Full  On Time  On Time In Full
# month
# March     2134244     5993     6492             4354
# June      2195275     6169     6631             4472
# April     2212599     6199     6728             4510
# July      2275074     6387     6958             4724
# May       2295811     6470     6898             4665
# August    2313933     6443     6898             4655

# %%
date1.groupby('month')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty').corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\774279303.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date1.groupby('month')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty').corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.991006  0.953928         0.941910
# In Full           0.991006  1.000000  0.959318         0.953631
# On Time           0.953928  0.959318  1.000000         0.994978
# On Time In Full   0.941910  0.953631  0.994978         1.000000

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date1_grouped_otif= date1.groupby('month')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date1_grouped_otif['Percentage of 1s'] = (date1_grouped_otif['sum'] /date1_grouped_otif['count']) * 100
date1_grouped_otif.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='green')
# Out:
# <Axes: xlabel='month'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date1_grouped_ot= date1.groupby('month')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date1_grouped_ot['Percentage of 1s'] = (date1_grouped_ot['sum'] /date1_grouped_ot['count']) * 100
date1_grouped_ot.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='red')
# Out:
# <Axes: xlabel='month'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date1_grouped_if= date1.groupby('month')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date1_grouped_if['Percentage of 1s'] = (date1_grouped_if['sum'] /date1_grouped_if['count']) * 100
date1_grouped_if.sort_values(by='Percentage of 1s').tail(5)['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='month'>

# %%
display(date1_grouped_if,date1_grouped_ot,date1_grouped_otif)
# Out:
#          sum  count  Percentage of 1s
# month
# April   6199   9428         65.750955
# August  6443   9738         66.163483
# July    6387   9684         65.954151
# June    6169   9390         65.697551
# March   5993   9103         65.835439
# May     6470   9753         66.338562
#          sum  count  Percentage of 1s
# month
# April   6728   9428         71.361901
# August  6898   9738         70.835901
# July    6958   9684         71.850475
# June    6631   9390         70.617678
# March   6492   9103         71.317148
# May     6898   9753         70.726956
#          sum  count  Percentage of 1s
# month
# April   4510   9428         47.836232
# August  4655   9738         47.802423
# July    4724   9684         48.781495
# June    4472   9390         47.625133
# March   4354   9103         47.830386
# May     4665   9753         47.831436

# %%
# In Full and On Time are not affetcted by month

# %%
date
# Out:
#              agreed_delivery_date  order_qty  On Time  In Full  \
# 0           Friday, March 4, 2022        110        1        1
# 1        Wednesday, March 2, 2022        347        1        1
# 2         Thursday, March 3, 2022        187        1        0
# 3           Friday, March 4, 2022        235        1        1
# 4         Thursday, March 3, 2022        176        1        1
# ...                           ...        ...      ...      ...
# 57091  Wednesday, August 31, 2022         24        1        1
# 57092  Wednesday, August 31, 2022         67        1        0
# 57093  Wednesday, August 31, 2022         41        1        0
# 57094  Wednesday, August 31, 2022         92        1        0
# 57095  Wednesday, August 31, 2022         29        0        1
#
#        On Time In Full
# 0                    1
# 1                    1
# 2                    0
# 3                    1
# 4                    1
# ...                ...
# 57091                1
# ...

# %%
def extract_day_of_week(df, column_name):
    df[column_name] = df[column_name].str.split(',').str[0]
    return df

extract_day_of_week(date,'agreed_delivery_date')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\3037229294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].str.split(',').str[0]
#       agreed_delivery_date  order_qty  On Time  In Full  On Time In Full
# 0                   Friday        110        1        1                1
# 1                Wednesday        347        1        1                1
# 2                 Thursday        187        1        0                0
# 3                   Friday        235        1        1                1
# 4                 Thursday        176        1        1                1
# ...                    ...        ...      ...      ...              ...
# ...

# %%
date.groupby('agreed_delivery_date')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\2610587488.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date.groupby('agreed_delivery_date')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
#                       order_qty  In Full  On Time  On Time In Full
# agreed_delivery_date
# Thursday                1900077     5339     5693             3848
# Tuesday                 1906660     5359     5737             3876
# Sunday                  1915052     5429     5829             3916
# Monday                  1916595     5310     5784             3864
# Friday                  1918014     5399     5835             3957
# Saturday                1924636     5382     5851             3938
# Wednesday               1945902     5443     5876             3981

# %%
date.groupby('agreed_delivery_date')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty').corr()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\3037521541.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date.groupby('agreed_delivery_date')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty').corr()
#                  order_qty   In Full   On Time  On Time In Full
# order_qty         1.000000  0.642243  0.868681         0.840899
# In Full           0.642243  1.000000  0.728373         0.843815
# On Time           0.868681  0.728373  1.000000         0.911751
# On Time In Full   0.840899  0.843815  0.911751         1.000000

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date_grouped_if= date.groupby('agreed_delivery_date')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date_grouped_if['Percentage of 1s'] = (date_grouped_if['sum'] /date_grouped_if['count']) * 100
date_grouped_if.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='agreed_delivery_date'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date_grouped_ot= date.groupby('agreed_delivery_date')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date_grouped_ot['Percentage of 1s'] = (date_grouped_ot['sum'] /date_grouped_ot['count']) * 100
date_grouped_ot.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='red')
# Out:
# <Axes: xlabel='agreed_delivery_date'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
date_grouped_otif= date.groupby('agreed_delivery_date')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
date_grouped_otif['Percentage of 1s'] = (date_grouped_otif['sum'] /date_grouped_otif['count']) * 100
date_grouped_otif.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='green')
# Out:
# <Axes: xlabel='agreed_delivery_date'>

# %%
display(date_grouped_otif,date_grouped_if,date_grouped_ot)
# Out:
#                        sum  count  Percentage of 1s
# agreed_delivery_date
# Friday                3957   8182         48.362259
# Monday                3864   8116         47.609660
# Saturday              3938   8197         48.041967
# Sunday                3916   8196         47.779405
# Thursday              3848   8057         47.759712
# Tuesday               3876   8106         47.816432
# Wednesday             3981   8242         48.301383
#                        sum  count  Percentage of 1s
# agreed_delivery_date
# Friday                5399   8182         65.986311
# Monday                5310   8116         65.426318
# Saturday              5382   8197         65.658168
# Sunday                5429   8196         66.239629
# Thursday              5339   8057         66.265359
# Tuesday               5359   8106         66.111522
# Wednesday             5443   8242         66.039796
#                        sum  count  Percentage of 1s
# agreed_delivery_date
# ...

# %%
# No biasness in the result for 'In Full','On Time','On Time In Full'

# %% [markdown]
# ## Analysed by customer_id

# %%
ci = df1[['customer_id','order_qty','In Full','On Time','On Time In Full']]

# %%
ci.groupby('customer_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\2346447922.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ci.groupby('customer_id')['order_qty','In Full','On Time','On Time In Full'].sum().sort_values(by='order_qty')
#              order_qty  In Full  On Time  On Time In Full
# customer_id
# 789520          363197      460      441              124
# 789501          371214     1175     1311              990
# 789403          372586     1205     1359             1037
# 789321          373499     1205     1342             1002
# 789522          373789     1174      413              302
# 789421          376425      493      421              137
# 789221          377036     1223     1354             1021
# 789201          377103     1204     1377             1031
# 789721          377436     1212     1361             1017
# 789720          378399     1211     1355             1001
# ...

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
ci_grouped_otif= ci.groupby('customer_id')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
ci_grouped_otif['Percentage of 1s'] = (ci_grouped_otif['sum'] /ci_grouped_otif['count']) * 100
ci_grouped_otif.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='green')
# Out:
# <Axes: xlabel='customer_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
ci_grouped_ot= ci.groupby('customer_id')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
ci_grouped_ot['Percentage of 1s'] = (ci_grouped_ot['sum'] /ci_grouped_ot['count']) * 100
ci_grouped_ot.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='red')
# Out:
# <Axes: xlabel='customer_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
ci_grouped_if= ci.groupby('customer_id')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
ci_grouped_if['Percentage of 1s'] = (ci_grouped_if['sum'] /ci_grouped_if['count']) * 100
ci_grouped_if.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='customer_id'>

# %%
# On Time In Full - 789122,789520,789421,789521,789522,789422,789420,789121,789601,789103,789903,789702
# On Time - 789122,789520,789421,789521,789522,789422,789420,789121
# In full - 789122,789520,789103,789903,789601,789421,789702

# %%
list1 = [789122,789520,789421,789521,789522,789422,789420,789121,789601,789103,789903,789702]
df1[df1['customer_id'].isin(list1)]
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 6        FMR33420203    Tuesday, March 1, 2022       789420    25891203
# 7        FMR34420402    Tuesday, March 1, 2022       789420    25891203
# 9        FMR34121203    Tuesday, March 1, 2022       789121    25891203
# 14       FMR34903603    Tuesday, March 1, 2022       789903    25891203
# 15       FMR32421203    Tuesday, March 1, 2022       789421    25891203
# ...              ...                       ...          ...         ...
# 57084  FAUG831121302  Tuesday, August 30, 2022       789121    25891202
# 57088  FAUG831522303  Tuesday, August 30, 2022       789522    25891303
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
#
#        order_qty        agreed_delivery_date        actual_delivery_date  \
# ...

# %%
df1[df1['customer_id'].isin(list1)][['customer_id','customer_name','city']].drop_duplicates()
# Out:
#      customer_id     customer_name       city
# 6         789420        Lotus Mart      Surat
# 9         789121          Coolblue  Ahmedabad
# 14        789903        Elite Mart   Vadodara
# 15        789421        Lotus Mart  Ahmedabad
# 19        789520  Acclaimed Stores      Surat
# 20        789702      Sorefoz Mart  Ahmedabad
# 30        789521  Acclaimed Stores  Ahmedabad
# 35        789422        Lotus Mart   Vadodara
# 41        789122          Coolblue   Vadodara
# 45        789103      Vijay Stores   Vadodara
# 51        789522  Acclaimed Stores   Vadodara
# 125       789601       Info Stores      Surat

# %%
## The supplies of those customer from these cities have to be improved in terms of 'In Full', 'On Time', 'On Time In full'

# %%
sns.kdeplot(data=df1,x='order_qty')
sns.kdeplot(data=df1,x='delivery_qty')
# Out:
# <Axes: xlabel='order_qty', ylabel='Density'>

# %%
df1['order_qty'].mean()
# Out:
# 235.16421465601795

# %%
df1['order_qty'].median()
# Out:
# 207.0

# %% [markdown]
# ## Analysing by VOFR % / Volume Fill rate will be total quantity shipped / total quantity ordered

# %%
vofr = df1[['customer_id','order_qty','delivery_qty','In Full','On Time','On Time In Full']]
vofr['total_order_qty'] = vofr.groupby('customer_id')['order_qty'].transform('sum')
vofr['total_delivery_qty'] = vofr.groupby('customer_id')['delivery_qty'].transform('sum')
vofr = vofr.drop(columns=['order_qty','delivery_qty'])
vofr
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\2272686047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vofr['total_order_qty'] = vofr.groupby('customer_id')['order_qty'].transform('sum')
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\2272686047.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vofr['total_delivery_qty'] = vofr.groupby('customer_id')['delivery_qty'].transform('sum')
#        customer_id  In Full  On Time  On Time In Full  total_order_qty  \
# ...

# %%
vofr['%vofr'] = vofr.groupby('customer_id').apply(
    lambda x: (x['total_delivery_qty'] / x['total_order_qty']) * 100
).reset_index(level=0, drop=True)

# %%
vofr = vofr.drop(columns=['total_order_qty','total_delivery_qty'])
vofr.sort_values(by='%vofr')
# Out:
#        customer_id  In Full  On Time  On Time In Full      %vofr
# 48303       789520        0        0                0  92.767561
# 42585       789520        0        0                0  92.767561
# 24659       789520        1        0                0  92.767561
# 24652       789520        0        0                0  92.767561
# 45577       789520        0        0                0  92.767561
# ...            ...      ...      ...              ...        ...
# 12638       789402        1        1                1  97.760342
# 30994       789402        1        1                1  97.760342
# 25821       789402        1        1                1  97.760342
# 26967       789402        1        1                1  97.760342
# 52259       789402        1        1                1  97.760342
#
# [57096 rows x 5 columns]

# %%
vofr[['customer_id','%vofr']].drop_duplicates().sort_values(by='%vofr')
# Out:
#      customer_id      %vofr
# 19        789520  92.767561
# 41        789122  92.828532
# 125       789601  92.840591
# 14        789903  92.916367
# 20        789702  92.986393
# 45        789103  93.052966
# 15        789421  93.219101
# 35        789422  97.273103
# 30        789521  97.281678
# 12        789102  97.288940
# 31        789720  97.320289
# 42        789101  97.335499
# 51        789522  97.371244
# 50        789202  97.373579
# 36        789301  97.383041
# 9         789121  97.388833
# 0         789203  97.389252
# 18        789621  97.424791
# 6         789420  97.437541
# 80        789622  97.449931
# 10        789501  97.504943
# 76        789201  97.522693
# 49        789221  97.539757
# 1         789320  97.556068
# 5         789721  97.580252
# 22        789603  97.592810
# 68        789321  97.610435
# 3         789220  97.611520
# 65        789503  97.627003
# 13        789902  97.633090
# 32        789401  97.645400
# 4         789703  97.693903
# ...

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
vofr_grouped_otif= vofr.groupby('customer_id')['On Time In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
vofr_grouped_otif['Percentage of 1s'] = (vofr1_grouped_otif['sum'] /vofr1_grouped_otif['count']) * 100
vofr_grouped_otif.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='green')
# Out:
# <Axes: xlabel='customer_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
vofr_grouped_ot= vofr.groupby('customer_id')['On Time'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
vofr_grouped_ot['Percentage of 1s'] = (vofr1_grouped_ot['sum'] /vofr1_grouped_ot['count']) * 100
vofr_grouped_ot.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3),color='red')
# Out:
# <Axes: xlabel='customer_id'>

# %%
# Group by 'Customer' and calculate the sum and count of 'Value' for each group
vofr_grouped_if= vofr.groupby('customer_id')['In Full'].agg(['sum', 'count'])

# Calculate the percentage of '1' values for each customer
vofr_grouped_if['Percentage of 1s'] = (vofr1_grouped_if['sum'] /vofr1_grouped_if['count']) * 100
vofr_grouped_if.sort_values(by='Percentage of 1s')['Percentage of 1s'].plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='customer_id'>

# %%
## Bad performance with these customer ids - 789122,789520,789903,789103,789601,789421,789702

# %%
df1[df1['customer_id'].isin([789122,789520,789903,789103,789601,789421,789702])][['customer_id','customer_name','city']].drop_duplicates()
# Out:
#      customer_id     customer_name       city
# 14        789903        Elite Mart   Vadodara
# 15        789421        Lotus Mart  Ahmedabad
# 19        789520  Acclaimed Stores      Surat
# 20        789702      Sorefoz Mart  Ahmedabad
# 41        789122          Coolblue   Vadodara
# 45        789103      Vijay Stores   Vadodara
# 125       789601       Info Stores      Surat

# %%
# These are customer id they need to focus in terms of %volumne rate

# %%
## Based on product

# %%
vofr1 = df1[['product_id','order_qty','delivery_qty','In Full','On Time','On Time In Full']]
vofr1['total_order_qty'] = vofr1.groupby('product_id')['order_qty'].transform('sum')
vofr1['total_delivery_qty'] = vofr1.groupby('product_id')['delivery_qty'].transform('sum')
vofr1 = vofr1.drop(columns=['order_qty','delivery_qty'])
vofr1
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\1497896669.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vofr1['total_order_qty'] = vofr1.groupby('product_id')['order_qty'].transform('sum')
# C:\Users\soumy\AppData\Local\Temp\ipykernel_23716\1497896669.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vofr1['total_delivery_qty'] = vofr1.groupby('product_id')['delivery_qty'].transform('sum')
#        product_id  In Full  On Time  On Time In Full  total_order_qty  \
# ...

# %%
vofr1['%vofr'] = vofr1.groupby('product_id').apply(
    lambda x: (x['total_delivery_qty'] / x['total_order_qty']) * 100
).reset_index(level=0, drop=True)

# %%
vofr1 = vofr1.drop(columns=['total_order_qty','total_delivery_qty'])
vofr1.sort_values(by='%vofr')
# Out:
#        product_id  In Full  On Time  On Time In Full      %vofr
# 21663    25891202        1        1                1  96.360975
# 20035    25891202        1        1                1  96.360975
# 20036    25891202        1        1                1  96.360975
# 20037    25891202        0        1                0  96.360975
# 20039    25891202        1        0                0  96.360975
# ...           ...      ...      ...              ...        ...
# 12046    25891501        0        1                0  96.852760
# 12047    25891501        0        0                0  96.852760
# 5896     25891501        0        1                0  96.852760
# 24126    25891501        1        0                0  96.852760
# 54773    25891501        1        0                0  96.852760
#
# [57096 rows x 5 columns]

# %%
vofr1.sort_values(by='%vofr')[['product_id','%vofr']].drop_duplicates()
# Out:
#        product_id      %vofr
# 21663    25891202  96.360975
# 51319    25891203  96.461991
# 34645    25891502  96.491071
# 15887    25891601  96.518908
# 56200    25891602  96.523476
# 28264    25891301  96.529917
# 20550    25891103  96.535704
# 9546     25891503  96.578956
# 10007    25891303  96.585135
# 17865    25891603  96.586625
# 36207    25891201  96.588916
# 5466     25891102  96.610749
# 32765    25891403  96.619629
# 45938    25891402  96.621027
# 47711    25891302  96.691366
# 50236    25891101  96.705415
# 27899    25891401  96.719668
# 45020    25891501  96.852760

# %%
# Here also we can see that it doesn't effect by the product

# %%
list2 = vofr1.sort_values(by='%vofr')[['product_id','%vofr']].drop_duplicates()['product_id'].unique()

# %%
df1[df1['product_id'].isin(list2)][['product_id','product_name','product_category']].drop_duplicates()
# Out:
#      product_id  product_name product_category
# 0      25891601       Tea 500        beverages
# 1      25891203    Butter 500            Dairy
# 20     25891302      Ghee 150            Dairy
# 37     25891301      Ghee 250            Dairy
# 59     25891102      Milk 250            Dairy
# 80     25891502  Biscuits 500             Food
# 95     25891403       Curd 50            Dairy
# 107    25891503  Biscuits 250             Food
# 123    25891103      Milk 100            Dairy
# 169    25891402      Curd 100            Dairy
# 187    25891201    Butter 100            Dairy
# 200    25891501  Biscuits 750             Food
# 214    25891602       Tea 250        beverages
# 234    25891101      Milk 500            Dairy
# 253    25891401      Curd 250            Dairy
# 265    25891603       Tea 100        beverages
# 283    25891202    Butter 250            Dairy
# 309    25891303      Ghee 100            Dairy

# %%
df1
# Out:
#             order_id      order_placement_date  customer_id  product_id  \
# 0        FMR34203601    Tuesday, March 1, 2022       789203    25891601
# 1        FMR32320302    Tuesday, March 1, 2022       789320    25891203
# 2        FMR33320501    Tuesday, March 1, 2022       789320    25891203
# 3        FMR34220601    Tuesday, March 1, 2022       789220    25891203
# 4        FMR33703603    Tuesday, March 1, 2022       789703    25891203
# ...              ...                       ...          ...         ...
# 57091  FAUG831420303  Tuesday, August 30, 2022       789420    25891303
# 57092  FAUG831122303  Tuesday, August 30, 2022       789122    25891303
# 57093  FAUG831702303  Tuesday, August 30, 2022       789702    25891303
# 57094  FAUG831221503  Tuesday, August 30, 2022       789221    25891303
# 57095  FAUG831202303  Tuesday, August 30, 2022       789202    25891303
#
#        order_qty        agreed_delivery_date         actual_delivery_date  \
# ...
